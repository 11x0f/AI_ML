# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %%
arr = np.array([[[0,0,0],              [255,255,255],          [0,0,0]],
                [[255,255,255],        [0,0,0],                [255,255,255]], 
                [[0,0,0],              [255,255,255],          [0,0,0]]])
plt.imshow(arr)
cv.imwrite("black_and_white_rgb.png", arr)
# Out:
# True

# %%
    R  G   B
    0  0   0  <--- black
