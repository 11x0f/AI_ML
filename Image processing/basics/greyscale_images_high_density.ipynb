# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2 as cv

# %%
#1280 X 720
img = []
for i in range(720):
    temp = []
    for j in range(1280):
        temp.append(1)
    img.append(temp)
img = np.array(img)
plt.imshow(img)

# %% [markdown]
# ### exporting image

# %%
cv.imwrite("img.png", img)
# Out:
# True

# %%
img = []
num=10
for i in range(256):
    temp = []
    for j in range(256):
        temp.append(i)
    img.append(temp)
    #num=(num+30)
img = np.array(img)
plt.imshow(img)
cv.imwrite("shades.png", img)
# Out:
# True
