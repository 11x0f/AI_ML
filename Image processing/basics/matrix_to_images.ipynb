# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = np.array([[1,1,1,0], [1,1,1,0], [1,0,0,0], [1,0,1,0]])
arr
# Out:
# array([[1, 1, 1, 0],
#        [1, 1, 1, 0],
#        [1, 0, 0, 0],
#        [1, 0, 1, 0]])

# %%
plt.imshow(arr)

# %%
from PIL import Image
img = Image.fromarray(arr)
display(img)
# Out:
# <PIL.Image.Image image mode=I size=4x4>

# %% [markdown]
# ## chessborad

# %%
zeros = np.zeros((8,8), dtype=int)

for i in range(8):
    for j in range(8):
        if (i+j)%2 ==0 :
            zeros[i][j]=1

plt.imshow(zeros)
